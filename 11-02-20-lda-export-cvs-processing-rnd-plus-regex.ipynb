# %% [markdown]
# ## Análsis de la Retroalimentación de Posadas y Gentera GPTW México
# ## Basado en muestra de datos de Net Promoter Score de ambos hoteles

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import string
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import concurrent.futures
import time
import pyLDAvis.sklearn
from pylab import bone, pcolor, colorbar, plot, show, rcParams, savefig
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import os
print(os.listdir("../input"))

# Plotly based imports for visualization
from plotly import tools
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff

# spaCy based imports
import spacy
from spacy.lang.es.stop_words import STOP_WORDS
from spacy.lang.es import Spanish
# !python -m spacy download es_core_news_sm

#Pandas display width
pd.set_option('max_colwidth',100) #max width df display
# Out:
# ['gptw08', 'gptw07']
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Requirement already satisfied: es_core_news_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.0.0/es_core_news_sm-2.0.0.tar.gz#egg=es_core_news_sm==2.0.0 in /opt/conda/lib/python3.6/site-packages (2.0.0)
# You are using pip version 10.0.1, however version 20.3b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
#     Linking successful
#     /opt/conda/lib/python3.6/site-packages/es_core_news_sm -->
#     /opt/conda/lib/python3.6/site-packages/spacy/data/es_core_news_sm
#
#     You can now load the model via spacy.load('es_core_news_sm')

# %%
# Data load in csv format
wines = pd.read_csv('../input/gptw08/dbgptwliderplus.csv')

wines.head(5)
# Out:
#              org                              ...                                                                                lider_minus
# 0  Grupo Posadas                              ...                                                                  Buen humor y es tolerante
# 1  Grupo Posadas                              ...                                                                            Estaré pasillos
# 2  Grupo Posadas                              ...                                                                                 Organizado
# 3  Grupo Posadas                              ...                               Puede dar oportunidades de como ayer un trabajo de excelente
# 4  Grupo Posadas                              ...                                                             HACER MAS PROYECTOS DE TRABAJO
#
# [5 rows x 8 columns]

# %%
wines.shape
# Out:
# (28409, 8)

# %% [markdown]
# ## Seccción para hacer los queries correspondientess, se requiere la selección de los valores de los campos de interés.
# ## El diseño utiliza "wines" como dataframe principal, utilizo "newdf" como auxiliar.
# ##  Validando la extracción correcta de la información, str.len para determinar número mínimo de carcteres

# %%
#selecting subsets of the dataframe, note the string length condition
#you have to select socre organization and ALSO the name of the field (column) to extract
newdf=wines[(wines['nps_score']>8)  & (wines['org']=="Gentera") & (wines['lider_minus'].str.len()>20)]
newdf.head(6)
# Out:
#            org                                   ...                                                                                               lider_minus
# 15128  Gentera                                   ...                                                aprender a escuchar, involucramiento con sus colaboradores
# 15129  Gentera                                   ...                                                                               Conocer más nuestra persona
# 15130  Gentera                                   ...                                                                          COMUNICACION Y TRABAJO EN EQUIPO
# 15131  Gentera                                   ...                                    Manejó del estrés , su forma de tratar a las personas es muy explosiva
# 15132  Gentera                                   ...                                                                                La capacitación constante
# 15137  Gentera                                   ...                                                              Recordar cuando le pides apoyo de un encargo
#
# [6 rows x 8 columns]

# %%
newdf.shape
# Out:
# (5202, 8)

# %% [markdown]
# ## Registra el numero de temas a identificar en la siguiente línea

# %%
#Aqui se define el numero de temas a buscar y el nombre del campo del data frame que contiene la informacion a analizar
total_topics=4
field_source='lider_minus'

# %%
# Reseting the index of the dataframe ****  *** very important resetting data frame index
newdf=newdf.reset_index(drop=True)
newdf.head(5)
# Out:
#        org                                   ...                                                                                               lider_minus
# 0  Gentera                                   ...                                                aprender a escuchar, involucramiento con sus colaboradores
# 1  Gentera                                   ...                                                                               Conocer más nuestra persona
# 2  Gentera                                   ...                                                                          COMUNICACION Y TRABAJO EN EQUIPO
# 3  Gentera                                   ...                                    Manejó del estrés , su forma de tratar a las personas es muy explosiva
# 4  Gentera                                   ...                                                                                La capacitación constante
#
# [5 rows x 8 columns]

# %%
newdf.shape
# Out:
# (5202, 8)

# %%
# To review element 
newdf[field_source][4]
#print(newdf.count)
# Out:
# 'La capacitación constante '

# %%
#Updating the wine df with the processed query
wines=newdf
wines.shape
# Out:
# (5202, 8)

# %%
#seleccionando campo fuente del dataframe 
wines[field_source][4]
# Out:
# 'La capacitación constante '

# %%
# Creando un objeto tipo Spacy
# En este caso el objeto es el modelo en Español
nlp = spacy.load('es_core_news_sm')

# %%
#Verficando que se esta procesando el registro correcto
doc = nlp(wines[field_source][4])
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">La capacitación constante </div>

# %% [markdown]
# ## Econtrando la raíz de los términos (Lemmatization)
# ## Creación de lista de puntuación y palabras comunes que no añaden mucha informaciónCY

# %%
#definicion de puntuacion y STOP WORDS
punctuations = string.punctuation
stopwords = list(STOP_WORDS)
stopwords.append('empresa') # added 'empresa' as a Stop Word

# %%
#Quitar signo de comentarios para revisar listas de stopwords y punctuations
#stopwords
#punctuations

# %%
review = str(" ".join([i.lemma_ for i in doc]))

# %%
doc = nlp(review)
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">La capacitación constante</div>

# %% [markdown]
# ## Detectando los componentes dentro de las frases ###

# %%
# POS tagging
for i in nlp(review):
    print(i,"=>",i.pos_)
# Out:
# La => DET
# capacitación => NOUN
# constante => ADJ

# %%
# Parser para las frases escritas Añadi len word >4 to filter out short words with no meaning in this exercise
parser = Spanish()
def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    mytokens = [ word.lower_ for word in mytokens ] #*either this line or the next one
    #mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ] #***this section keeps only the lemma removed
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations and len(word)>4] #Eliminating short words
    mytokens = " ".join([i for i in mytokens])
    return mytokens

# %%
# utilizando la variable field_source como la columna a analizar de la base de datos
spacy_tokenizer(wines[field_source][4])
# Out:
# 'capacitación constante'

# %%
spacy_tokenizer('realmente no lo sé xq sólo se dedica a gritarnos  no tiene manera d decir las cosas sin saltarse')
# Out:
# 'realmente dedica gritarnos saltarse'

# %%
spacy_tokenizer('pues creo q ninguna porque nos trata como personas inutiles aparte es muy alzado hasta vemos')
# Out:
# 'personas inutiles aparte alzado vemos'

# %%
# Applies the parser and filters information to get a processed data frame
# Important selection on the column of the wines field_source
tqdm.pandas()
wines["processed_source"] = wines[field_source].progress_apply(spacy_tokenizer)
# Out:
# 100%|██████████| 5202/5202 [00:02<00:00, 1737.67it/s]

# %%
wines["processed_source"][0:4]
# Out:
# 0    aprender escuchar involucramiento colaboradores
# 1                                            persona
# 2                                comunicacion equipo
# 3      manejó estrés forma tratar personas explosiva
# Name: processed_source, dtype: object

# %% [markdown]
# ## Encontrando los temas principales entre todos los documentos
#
# ## Creación de un vector de términos

# %% [markdown]
# ## Aquí es donde se hace el fit a la vectorizacion de la data!

# %%
# Creating a vectorizer version without the stop words option
vectorizer = CountVectorizer( lowercase=True, token_pattern='[a-zA-Z\-][a-zA-Z\-]{2,}')
data_vectorized = vectorizer.fit_transform(wines["processed_source"]) #procesando processed source
#type(data_vectorized)
data_vectorized.shape
# Out:
# (5202, 3985)

# %%
NUM_TOPICS = total_topics #parametro desde el principio

# %%
# Latent Dirichlet Allocation Model ADDED random_state = 42 to reproduce results
lda = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=20, learning_method='online',verbose=True,random_state=42)
data_lda = lda.fit_transform(data_vectorized)
lda.components_.shape
#type(data_lda)
#print(data_lda.shape)
#type(data_lda)
# Out:
# iteration: 1 of max_iter: 20
# iteration: 2 of max_iter: 20
# iteration: 3 of max_iter: 20
# iteration: 4 of max_iter: 20
# iteration: 5 of max_iter: 20
# iteration: 6 of max_iter: 20
# iteration: 7 of max_iter: 20
# iteration: 8 of max_iter: 20
# iteration: 9 of max_iter: 20
# iteration: 10 of max_iter: 20
# iteration: 11 of max_iter: 20
# iteration: 12 of max_iter: 20
# iteration: 13 of max_iter: 20
# iteration: 14 of max_iter: 20
# iteration: 15 of max_iter: 20
# iteration: 16 of max_iter: 20
# iteration: 17 of max_iter: 20
# iteration: 18 of max_iter: 20
# iteration: 19 of max_iter: 20
# iteration: 20 of max_iter: 20
# (4, 3985)

# %%
# Non-Negative Matrix Factorization Model
nmf = NMF(n_components=NUM_TOPICS)
data_nmf = nmf.fit_transform(data_vectorized)

# %%
# Latent Semantic Indexing Model using Truncated SVD
lsi = TruncatedSVD(n_components=NUM_TOPICS)
data_lsi = lsi.fit_transform(data_vectorized)

# %%
# function printing keywords for each topic       *** You may select top terms ***
def selected_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):    #idx and topic become a vector for each iteration through the enumerate command
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i])     #very cleverly algins the names in vectorizer with the topics in model components
                        for i in topic.argsort()[:-top_n - 1:-1]]) # i here is the index orders in descinding mode keep the first 10 value stop value is -11 to

# %%
# Keywords for topics clustered by Latent Dirichlet Allocation
print("LDA Model:")
selected_topics(lda, vectorizer)
# Out:
# LDA Model:
# Topic 0:
# ['falta', 'equipo', 'organizaci', 'comunicaci', 'ocasiones', 'confianza', 'puesto', 'caracter', 'actividades', 'tiempos']
# Topic 1:
# ['escuchar', 'colaboradores', 'trato', 'personas', 'seguimiento', 'der', 'apoyo', 'colaborador', 'cargo', 'hablar']
# Topic 2:
# ['persona', 'personal', 'oportunidad', 'apoyo', 'forma', 'mejorar', 'gente', 'car', 'cter', 'campo']
# Topic 3:
# ['equipo', 'organizacion', 'lider', 'clientes', 'paciencia', 'decisiones', 'manejo', 'conocimiento', 'aprender', 'tomar']

# %% [markdown]
# ## Habilitar para análsis NMF

# %%
# Keywords for topics clustered by Latent Semantic Indexing
#print("NMF Model:")
#selected_topics(nmf, vectorizer)

# %% [markdown]
# ## Habilitar para análsis LSI

# %%
# Keywords for topics clustered by Non-Negative Matrix Factorization
#print("LSI Model:")
#selected_topics(lsi, vectorizer)

# %% [markdown]
# ## Identificando documentos correspondientes a cada tema

# %%
# function printing documents belonging to each topic  *** You may select # of top documents ***
def selected_documents(model,wines2,top_n=30):
    numtemas, tempvar = model.components_.shape
    print("Printing Document belonging to each topic")
    for idx in range(numtemas): #idx and topic become a vector for each iteration through each topic 
        print(" ")
        print("Topic %d:" % (idx))
        print(" ")
        ptop_indices=np.argsort(doc_topic[:,idx])[:-top_n-1:-1] #sorting the indices by the offset column 1 in reverse order, top indices gives the order document
        print(wines2[ptop_indices])
        if (idx==0):
            dfcsvtmp=wines2[ptop_indices].to_frame()  #note the use to frame method as the results were just a series
            dfcsvtmp.insert(1,"orig_topic",idx) #during the first iteration add the column named tema with value idx zero in first iteration
            print(idx)
        else:
            dfcsvtmp2=wines2[ptop_indices].to_frame() #note the use to frame method as the results were just a series
            dfcsvtmp2.insert(1,"orig_topic",idx) # use a tmp dataframe to add the column named tema and fill it with the current idx iteration
            dfcsvtmp=dfcsvtmp.append(dfcsvtmp2) # append to previous data frame including the tema column
    return dfcsvtmp #returning the data frame including all comments and temas
        #print (doc_topic[ptop_indices]) #Uncomment to see probabilities by topic

# %%
print(lda.components_.shape)
# Out:
# (4, 3985)

# %%
# for each document calculate the probability for each topic in column form *** VERY IMPORTANT ***
doc_topic=lda.transform(data_vectorized) 
doc_probs=pd.DataFrame(doc_topic)
#Top documents by topic
# You can change to the label "processed_source" below to see the parsed sentences in the following line
dfcsv=selected_documents(lda,wines[field_source].str.lower()) #converting results to lower case
# Out:
# Printing Document belonging to each topic
#
# Topic 0:
#
# 611     cambia constantemente de estrategias sin dar un tiempo determinado para probar funcionen, a vece...
# 240     le falta trabajar en equipo\nle falta empatia\nevitar las prefetencias\nno conoce la formacion p...
# 295     planificar mejores estrategias.  saber realmente los problemas que hay en cada cuenta el porcque...
# 367     falta de liderazgo\ntrabajo en equipo\nacuerdos con terceros sin respaldar al.comaborador\nfalta...
# 335     implementación de nuevas estrategias de venta, cambiar las estrategias para alcanzar los objetiv...
# 1135    es muy obsesivo con tener todo perfecto, y esto hace que trabajemos con bitácoras tras bitácoras...
# 541     no se explicarlo porque a veces siento que le da mucha flohera hacer las cosas pero al fibal de ...
# 166          liderazgo y trabajo en equipo, sabe guiar y orientar, fortalece las actividades mas complejas.
# 3143    es importante integrar al equipo se pueden realizar actividades que fomenten la confianza y trab...
# 4909                                           falta de organización en eventos extras del ambiente laboral
# 5089                                       mensajes repetitivos en distintos medios con similar información
# 225                       -exceso de confianza\n-visita poco a los equipos de trabajo\n-falta de constancia
# 479     exceso de confianza. creo que debe procurar cuidar nuestro area de trabajo, bajo los criterios e...
# 4663                      organización, por las actividades que tiene en ocasiones es difícil contactarla.
# 790                                            se olvida que hay tiempos de horario laboral\nno es objetivo
# 564                                  evade el conflicto\npromover el trabajo de sus subornidados directos\n
# 4847                                         su tenacidad la ciega y aceves no reconoce cuando se equivoca
# 3395        realmente que dependa de el ninguna, el unico que veo es que tiene una agendra muy sobrecargada
# 1777          que a veces tardamos mucho en oficina  por las tardes sin hacer nada esperando para reportar
# 1528                                 no tiene mucha comunicacion con el quipo.\nle falta integrar al aquipo
# 1588                                              cambiar caracter \ndiferenciar lobpersonal con lo laboral
# 4025                 son muchas una de ellas es ascender de puesto y cambiar de ciudad con un sueldo mejor.
# 3311          perfeccionista que no esta mal para mi punto de vista solo que en ocasiones es muy aprensivo
# 1893                                                        le falta generae realtad\nle falta mas humildad
# 1235                                            no delega actividades y falta de comunicación con su equipo
# 888                   un mayor enfoke en la rentabilidad diaria medible ser mejor de lo q somos como equipo
# 819                             hasta el momento a sabiado administra bien la oficina y al equipo de venyas
# 1300                                              escucha activa, trabajo en equipo, sensibilidad, empatia.
# 699                comprometida en sus actividades y ve la manera de resolverlas y salir a flote el trabajo
# 2738                                       aveces no escucha a su equipo y toma una accion antes de decidir
# Name: lider_minus, dtype: object
# 0
#
# Topic 1:
#
# 196     organizarse su trabajo en cuanto a las capturas, distribuir el trabajo con el auxiliar, porque l...
# 4059    que sea mas acecible cuado desayu emos.\ncua do salio con migo no queria detenerse a comer y o n...
# 2664    es bipolar\nactua viceralmente\ntiene mal genio\nno es sociable\nes celoso de su trabajo y cuand...
# 91      tiene preferencias, no convive igual con todos los empleados a muchos ni saluda, no sabe que hac...
# 1924    lugar de recidencia. tiene que hacer traslado grande en kilómetros, lo cual lo puede exponer a u...
# 261        ea muy sarcástica, se toma las cosas como personales, hace caras y tiene a alguien como favorito
# 788                        permitir que los proceso maduren y no hacer cambios tan rápido o anticipadamente
# 5114    agrede a sus colaboradores en el lugar donde se encuentre y no da formalidad. ofende por via tel...
# 3543                            que aprenda a escuchar a las personas y muestre apoyo cuando se le requiera
# 78                                que aveces su enojo se hace muy evidente y llega a perder la objetividad
# 2818         tiene que ser objetiva,  dejar de ser chismosa \nno hablar mal de las personas a sus espaldas
# 1087    ser mas preciso con las cosas q se requieren de cada uno , no romper esa limea de jefe inmediato...
# 742        ser ms amable co las personas que tiene a su cargo el.por que aveces se le sube mucho el.orgullo
# 3497                escuchar las necesidades de los colaboradores con respecto alas activividades laborales
# 3993                                              trato a sus súbditos y mejora en la conducción al cliente
# 2105                   por ser demasiado humana-consciente, el colaborador mal interpreta y abusa de ello.
# 515           que pueda dar mas seguimientos y responder rapidamente alguna duda que se llegase a presentar
# 2242    pues que se mezcle un poco mas con uno deves en cuando que muestre mas interes sobre uno y su fa...
# 323                estar un poco mas atenta a las necesidades que se requieran, cuando surja un incidencia.
# 5190                      se predispone cuando cuestiona algo, no consulta el estatus o la versión antes de
# 5037                                      que sea más abierto a las situaciones externas que puedan influir
# 77                            dar seguimiento constante para saber el avance de cada colaborador a su cargo
# 900                                             el trato con las personas / el servicio al cliente interno
# 2570                                compartir y abundar un poco más en temas de implementación de cambios.
# 3016                                          sanciones a colaboradores que no dan un oportuno seguimiento
# 11                                                    darse el tiempo para contestar los correos en seguida
# 3599                                                                 pues específicamente no sabría decirle
# 783                                              escuchar a los analistas y enrolarse mas con la operación
# 4922                                                                   indiferente, egocéntrico, clasista.
# 706     incongruencia con lo que dice y lo que hace, de repente llega a tener preferencias y se base en ...
# Name: lider_minus, dtype: object
#
# Topic 2:
#
# 2542    ella decide quien crece y quien no, no nos da oportunidad de crecer y ciente tener el derecho de...
# 491     ninguna por por mas advertencias  que le den siguecon sus mismos malos modos y formas pesimas  d...
# 3545    no acepta ir a lugares lejanos no acompaña de forma regular para verificar la función de los gru...
# 2837    estar mas al pendiente del área de sucursales,  gestionar bien, que sucursales necesitan persona...
# 1728    veo oportunidad para sincronizar el apoyo de las areas de servicio para hacerlas de manera homog...
# 825     no sólo mantener - trabajar la agenda que desde dirección o desde él se genera, sino buscar alia...
# 3825    que quizás es permisible, cosa que con gente adulta, no hay problema, sin embargo hay gente con ...
# 67      modos y formas \nte corrige utilizando palabras qué te evidencian en lugar que te inspiren hacer...
# 326     decirnos en que necesitamos mejorar, ayudarnos a nosotros también a trabajar en áreas de oportun...
# 2497    que necesita sonreir un poco mas, su aspecto pareciera que esta siempre enojada jijij aunque se ...
# 2149                              carácter, inflexible en opiniones y acciones, poco abierta a sugerencias
# 37      no acepta opiniones de subordinados, no cambia su esquema para trabajar, hay favoritismos, es so...
# 4056                       control de su carácter, sobrellevar una conversación sin llegar a la alteración
# 20                           necesita actualizar su forma de trabajar, esta acostumbrado a la vieja escuela
# 224                 puede llegar a ser subgerente.. \nmaneja muy bien su postura.. en un equilibrio exacto.
# 156                tratar de marcar su linea entre promotores y el de administrador.\n\nmenos flexibilidad.
# 1911    tiene que buscar espacios para descansar más, ya que últimamente ha estado sujeta a demasiado es...
# 727                                      su carácter fuerte. a veces no tiene tacto para tratar al personal
# 289     si tiene un problema no lo habla con la persona correcta lo dice a todos y hasta el ultimo lo di...
# 2905                                       su carácter, la forma de dirigirse y tratar a las personas .\n\n
# 3                                    manejó del estrés , su forma de tratar a las personas es muy explosiva
# 674                           humildad, escucha ser docil al dar areas de oportunidad ser menos sarcasrico
# 1509                                             posponerse para sub gerente o gerente\ncrecer como persona
# 2283    a veces es muy serio y no sabemos si esta enojado\nejemplo: a veces esta muy serio y no sabemos ...
# 2100                                no tiene madera de ventas y solo piensa en su propio beneficio personal
# 4933                 ella es una persona muy metódica y siempre está dispuesta a apoyarnos a todas y todos
# 3831                                               nivel de exigencia homogéneo, pero creo que es normal...
# 939     de la forma que hemos llevado las cosas creo que son las correctas y áreas de oportunidad no veo...
# 4862    a veces no se dedica al 100% porque funciona mas como asistente del gerente casi lo realiza todo...
# 2040           no poder estar en todas las oficinas. es muchi trabajo o son muchad las oficinas que atiende
# Name: lider_minus, dtype: object
#
# Topic 3:
#
# 116     ser más empatica, no hacerse de falsas ideas en cuanto a los clientes, ser igual con todos tanto...
# 4624    tener un mayor dominio de popup, mejor organizacion en su correo y una estrategia para ver el tr...
# 4048    de mi jefe directo ninguna de el jefe de el que es nuestro director brígido michel rodríguez ser...
# 4448        en la negociacion de un pago. no ser tan agresivo.porq puede ocasionar un problrna.mas moderado
# 1367    es muy estricto y firrme a beses de maciado lineal en su andar y hay veces que tambien hay k ser...
# 5179      la rigidez para seguir los procesos, no tomar en cuenta ideas de los demás para funcionar mejor.
# 2678    hace reuniones de un momento a otro sin previo aviso, estas son muy frecuentes. es decir, no ten...
# 3788    en ocaciones no hay coherencia en lo que dice y lo que hace, p. ej. pide tableros actualizaos cu...
# 2147    priorizar requerimientos y saber decir no a los requerimeintos que no pertenecen al tramo de con...
# 1987                               es insegura al tomar algunas decisiones y requiere capacitación en excel
# 805      que se respete las decisiones ya tomadas a los promotores y que no las cambien no más sin avisar.
# 1773              trabajo en equipo uninirnos vas como equipo de trabajo unirnos mas como unidad de negocio
# 697     una mejor preparacion en los procesos, y en la aplicacion de los mismos, esto a traves de la lec...
# 327                           darle mas importancia a detalles pequeños y opacar el buen trabajo que asemos
# 940     quiza podria fomentar mas la convivencia e integrar mas al equipo en los momentos que tenemos ju...
# 325              apegarse al código de ética y a los valores que marca la empresa, no hay trabajo en equipo
# 4006                                                 en mi lider terminar sus estudios seguir preparandose
# 73                          seguir siendo asi como es y q siga aprendoendo para q pueda seguir enseñandonos
# 1427                                       seria el no darnos tanta co fianza ya es buena pero no en ecxeso
# 4525                          la inclusión, una gran ventaja sería abrir la puerta a otro tipo de perfiles
# 1417                           que sea mas humilde y menos expresiva ya que sus tratos perecen despectivos
# 5100                                            ética, estudios, filosofía, conocimiento, trabajo en equipo
# 803                        podría analizar más a fondo las capacidades del equipo para retarlo un poco más.
# 120                                       tomar encuanta al equipo en algunas ocaciones para alguna actidad
# 2063                                      involucramiento en los diversos temas que se viven en mi región.
# 372     en ciertos temas, podría tomar decisiones de manera más rápida, principalmente cuando hay contex...
# 1402    debe tener mas rigor para con los clientes y debe apoyar a todos sus promotores por igual ser ma...
# 58                             trabajo en equipo y conocimiento en algunos temas de soporte en la operacion
# 198                                         saber dirigir los conflictos \ncouching al equipo de promotores
# 132                     el cómo pedir las cosas para trabajar a  sus compañeros ( en el pedir está el dar.)
# Name: lider_minus, dtype: object

# %%
dfcsv.head()
# Out:
#                                                                                              lider_minus  orig_topic
# 611  cambia constantemente de estrategias sin dar un tiempo determinado para probar funcionen, a vece...           0
# 240  le falta trabajar en equipo\nle falta empatia\nevitar las prefetencias\nno conoce la formacion p...           0
# 295  planificar mejores estrategias.  saber realmente los problemas que hay en cada cuenta el porcque...           0
# 367  falta de liderazgo\ntrabajo en equipo\nacuerdos con terceros sin respaldar al.comaborador\nfalta...           0
# 335  implementación de nuevas estrategias de venta, cambiar las estrategias para alcanzar los objetiv...           0

# %%
doc_probs.iloc[4059,0:4]
# Out:
# 0    0.025023
# 1    0.924933
# 2    0.025021
# 3    0.025023
# Name: 4059, dtype: float64

# %%
doc_probs.head()
# Out:
#           0         1         2         3
# 0  0.050002  0.450182  0.050002  0.449814
# 1  0.125001  0.125001  0.624996  0.125001
# 2  0.743227  0.083334  0.083334  0.090104
# 3  0.035721  0.036857  0.891662  0.035760
# 4  0.083342  0.416829  0.083341  0.416489

# %%
comments_tab=pd.concat([dfcsv, doc_probs], axis=1, join='inner') #inner joing by index of top n doc with idx and probs ****

# %%
comments_tab.head(10)
# Out:
#                                                                                               lider_minus    ...            3
# 611   cambia constantemente de estrategias sin dar un tiempo determinado para probar funcionen, a vece...    ...     0.021088
# 240   le falta trabajar en equipo\nle falta empatia\nevitar las prefetencias\nno conoce la formacion p...    ...     0.022984
# 295   planificar mejores estrategias.  saber realmente los problemas que hay en cada cuenta el porcque...    ...     0.022744
# 367   falta de liderazgo\ntrabajo en equipo\nacuerdos con terceros sin respaldar al.comaborador\nfalta...    ...     0.025584
# 335   implementación de nuevas estrategias de venta, cambiar las estrategias para alcanzar los objetiv...    ...     0.025300
# 1135  es muy obsesivo con tener todo perfecto, y esto hace que trabajemos con bitácoras tras bitácoras...    ...     0.027796
# 541   no se explicarlo porque a veces siento que le da mucha flohera hacer las cosas pero al fibal de ...    ...     0.031277
# 166        liderazgo y trabajo en equipo, sabe guiar y orientar, fortalece las actividades mas complejas.    ...     0.032218
# 3143  es importante integrar al equipo se pueden realizar actividades que fomenten la confianza y trab...    ...     0.032563
# 4909                                         falta de organización en eventos extras del ambiente laboral    ...     0.035721
#
# [10 rows x 6 columns]

# %%
#doc_probs   undocuments to see probabilities

# %%
type(wines)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Seccion de prueba para una frase

# %%
# Example of transformation of an individual sentence with its probabilities for each topic
text = spacy_tokenizer("Conoce mucho es perservarnte y simpre predica con el ejemplo muy inteligente")
x = lda.transform(vectorizer.transform([text]))[0]
print('Probabilities by topic (count start with zero): ',x)
print()
print("El tema con mayor probabilidad usando modelo LDA es el tema #",np.argmax(x))
# Out:
# Probabilities by topic (count start with zero):  [0.45364688 0.44625191 0.05004968 0.05005153]
#
# El tema con mayor probabilidad usando modelo LDA es el tema # 0

# %% [markdown]
# ## Visualizando los Resultado de LDA con la utilería pyLDAvis

# %%
pyLDAvis.enable_notebook()
dash = pyLDAvis.sklearn.prepare(lda, data_vectorized, vectorizer, mds='tsne')
dash
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 2      -78.671196 -396.283112       1        1  27.474965
# 0      -33.778664   -7.443441       2        1  25.272522
# 3      138.194778 -224.309540       3        1  24.350190
# 1     -250.644653 -179.417053       4        1  22.902322, topic_info=     Category        Freq           Term       Total  loglift  logprob
# term
# 1777  Default  231.000000          falta  231.000000  30.0000  30.0000
# 1541  Default  379.000000         equipo  379.000000  29.0000  29.0000
# 1578  Default  170.000000       escuchar  170.000000  28.0000  28.0000
# 668   Default  144.000000  colaboradores  144.000000  27.0000  27.0000
# 2765  Default  106.000000     organizaci  106.000000  26.0000  26.0000
# 2897  Default  114.000000        persona  114.000000  25.0000  25.0000
# 768   Default  106.000000     comunicaci  106.000000  24.0000  24.0000
# 2898  Default  107.000000       personal  107.000000  23.0000  23.0000
# 2678  Default   89.000000      ocasiones   89.000000  22.0000  22.0000
# 3869  Default   79.000000          trato   79.000000  21.0000  21.0000
# 805   Default   83.000000      confianza   83.000000  20.0000  20.0000
# 2768  Default   80.000000   organizacion   80.000000  19.0000  19.0000
# 2737  Default  105.000000    oportunidad  105.000000  18.0000  18.0000
# 1843  Default   84.000000          forma   84.000000  17.0000  17.0000
# 3176  Default   76.000000         puesto   76.000000  16.0000  16.0000
# 3511  Default   69.000000    seguimiento   69.000000  15.0000  15.0000
# 2457  Default   79.000000        mejorar   79.000000  14.0000  14.0000
# 1909  Default   79.000000          gente   79.000000  13.0000  13.0000
# 569   Default   72.000000       caracter   72.000000  12.0000  12.0000
# 1014  Default   76.000000           cter   76.000000  11.0000  11.0000
# 566   Default   76.000000            car   76.000000  10.0000  10.0000
# 91    Default   71.000000    actividades   71.000000   9.0000   9.0000
# 543   Default   74.000000          campo   74.000000   8.0000   8.0000
# 2314  Default   65.000000          lider   65.000000   7.0000   7.0000
# 304   Default  128.000000          apoyo  128.000000   6.0000   6.0000
# 2904  Default  107.000000       personas  107.000000   5.0000   5.0000
# 3184  Default   69.000000    puntualidad   69.000000   4.0000   4.0000
# 646   Default   61.000000       clientes   61.000000   3.0000   3.0000
# 3784  Default   60.000000        tiempos   60.000000   2.0000   2.0000
# 3262  Default   55.000000           reas   55.000000   1.0000   1.0000
# ...       ...         ...            ...         ...      ...      ...
# 2900   Topic4   30.548758     personales   31.176244   1.4536  -4.8679
# 277    Topic4   30.230772       apertura   30.852407   1.4536  -4.8783
# 2591   Topic4   29.588951    necesidades   30.220070   1.4528  -4.8998
# 3016   Topic4   28.818608   preferencias   29.442827   1.4525  -4.9262
# 820    Topic4   28.347390     congruente   28.969886   1.4522  -4.9427
# 645    Topic4   28.473225        cliente   29.098677   1.4522  -4.9382
# 870    Topic4   22.899483      constante   23.520639   1.4472  -5.1561
# 913    Topic4   21.767887      controlar   22.392546   1.4456  -5.2067
# 1921   Topic4   20.049453          gesti   20.673955   1.4433  -5.2890
# 446    Topic4   18.907659          ayuda   19.540928   1.4410  -5.3476
# 3745   Topic4   18.364301   temperamento   18.983497   1.4408  -5.3768
# 539    Topic4   17.730515        cambios   18.352412   1.4395  -5.4119
# 2348   Topic4   19.233240          llega   19.910463   1.4393  -5.3305
# 2558   Topic4   17.061460        motivar   17.690064   1.4378  -5.4504
# 889    Topic4   16.090897      contestar   16.701743   1.4367  -5.5089
# 2012   Topic4   15.328974       horarios   15.958850   1.4337  -5.5574
# 717    Topic4   15.203762      compartir   15.833789   1.4333  -5.5656
# 3108   Topic4   14.855974       producto   15.485454   1.4324  -5.5888
# 2008   Topic4   14.573830     honestidad   15.206217   1.4315  -5.6080
# 3634   Topic4   14.160463     soluciones   14.783052   1.4309  -5.6367
# 819    Topic4   14.110721    congruencia   14.734655   1.4307  -5.6403
# 1903   Topic4   14.716201        generar   15.376876   1.4300  -5.5982
# 3022   Topic4   13.511780       prefiero   14.121503   1.4298  -5.6836
# 14     Topic4   14.366790        abierto   15.021763   1.4294  -5.6223
# 2904   Topic4   74.333913       personas  107.816756   1.1021  -3.9786
# 581    Topic4   34.691925          cargo   63.652410   0.8670  -4.7407
# 3596   Topic4   25.411902    situaciones   39.242409   1.0394  -5.0520
# 304    Topic4   39.127235          apoyo  128.849054   0.2821  -4.6204
# 3715   Topic4   20.831384          tacto   34.440000   0.9712  -5.2507
# 1126   Topic4   16.194032          dejar   20.174046   1.2542  -5.5025
#
# [175 rows x 6 columns], token_table=      Topic      Freq               Term
# term
# 14        4  0.931981            abierto
# 60        1  0.971573       acercamiento
# 75        1  0.984957             acompa
# 85        1  0.963145            actitud
# 87        2  0.982204             activa
# 91        2  0.993280        actividades
# 224       1  0.979967            amiento
# 277       4  0.972371           apertura
# 296       2  0.994183              apoya
# 298       3  0.993539             apoyar
# 304       1  0.690731              apoyo
# 304       4  0.302680              apoyo
# 311       3  0.990570           aprender
# 333       1  0.727717              areas
# 333       3  0.251902              areas
# 383       3  0.976318             atenci
# 384       2  0.974730           atencion
# 437       2  0.738434             aveces
# 437       4  0.268522             aveces
# 446       4  0.972318              ayuda
# 539       4  0.980798            cambios
# 543       1  0.994226              campo
# 548       3  0.995215          capacidad
# 566       1  0.991508                car
# 569       2  0.993212           caracter
# 581       1  0.455599              cargo
# 581       4  0.549861              cargo
# 645       4  0.962243            cliente
# 646       3  0.995560           clientes
# 654       2  0.969990           cobranza
# ...     ...       ...                ...
# 3183      3  0.976907            puntual
# 3184      1  0.986215        puntualidad
# 3259      2  0.947369          realmente
# 3262      1  0.981687               reas
# 3278      2  0.983131          reconocer
# 3394      3  0.977899    responsabilidad
# 3395      2  0.977064  responsabilidades
# 3410      1  0.963826         resultados
# 3427      3  0.989781    retroalimentaci
# 3511      4  0.997729        seguimiento
# 3513      3  0.967197             seguir
# 3596      1  0.331274        situaciones
# 3596      4  0.637066        situaciones
# 3634      4  0.947030         soluciones
# 3664      1  0.971233       subordinados
# 3715      1  0.377468              tacto
# 3715      4  0.609756              tacto
# 3740      3  0.658092              temas
# 3740      4  0.340393              temas
# 3745      4  0.948192       temperamento
# 3782      2  0.977719               tico
# 3784      2  0.982311            tiempos
# 3804      3  0.982212         tolerancia
# 3805      2  0.950972          tolerante
# 3813      3  0.974712              tomar
# 3865      1  0.987999             tratar
# 3869      4  0.998077              trato
# 3888      3  0.993021             unidad
# 3926      1  0.983518             ventas
# 3958      2  0.933907              vista
#
# [155 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 1, 4, 2])

# %%
#getting topic coordinates, making name adjustments and adding original topic column
#print(dash.topic_coordinates)
coordinates=pd.DataFrame(dash.topic_coordinates)
coordinates.rename(columns = {'topics':'Topic'}, inplace = True) #changing the field name to Topic
coordinates['Topic'] = 'Topic' + coordinates['Topic'].astype(str) #adding the string "Topic" and then adding the value
coordinates.head(10)
coordinates['orig_topic'] = coordinates.index #create a column based on the original index
coordinates.head(10)
#coordinates.to_csv('coordinates_std.csv')
# Out:
#                 x           y     ...           Freq  orig_topic
# topic                             ...
# 2      -78.671196 -396.283112     ...      27.474965           2
# 0      -33.778664   -7.443441     ...      25.272522           0
# 3      138.194778 -224.309540     ...      24.350190           3
# 1     -250.644653 -179.417053     ...      22.902322           1
#
# [4 rows x 6 columns]

# %%
topic_map = coordinates[['orig_topic', 'Topic']]
topic_map.head()
# Out:
#        orig_topic   Topic
# topic
# 2               2  Topic1
# 0               0  Topic2
# 3               3  Topic3
# 1               1  Topic4

# %%
#converting the topic_map to a dictionary to be used later to rename columns accordingly
#the dictionary has two elements one named orig_topic and the second one named "Topic"
diccionario=topic_map.to_dict()
print(diccionario['Topic'])
# Out:
# {2: 'Topic1', 0: 'Topic2', 3: 'Topic3', 1: 'Topic4'}

# %%
#print(dash.topic_info)
topic_info=pd.DataFrame(dash.topic_info)
topic_info.rename(columns = {'Category':'Topic'}, inplace = True) #renaming the category field|
topic_info = topic_info[topic_info['Topic'] != 'Default'] #removing any records with "default" description 
topic_info.head(10)
# Out:
#        Topic        Freq         Term       Total  loglift  logprob
# term
# 2897  Topic1  113.650689      persona  114.282459   1.2864  -3.7361
# 2898  Topic1  106.751725     personal  107.382346   1.2860  -3.7987
# 1843  Topic1   84.162680        forma   84.792740   1.2844  -4.0365
# 1909  Topic1   78.390507        gente   79.016127   1.2839  -4.1075
# 1014  Topic1   76.035493         cter   76.650908   1.2838  -4.1380
# 566   Topic1   76.035493          car   76.650908   1.2838  -4.1380
# 2457  Topic1   78.743070      mejorar   79.382475   1.2838  -4.1030
# 543   Topic1   73.806420        campo   74.429781   1.2835  -4.1678
# 3184  Topic1   69.339913  puntualidad   69.964438   1.2829  -4.2302
# 75    Topic1   54.210871       acompa   54.824744   1.2806  -4.4763

# %%
#merging original topic mapping with new mapping for topic_info
merged_topic_info = pd.merge(topic_map,topic_info,on="Topic",how='inner')
merged_topic_info.head(10)
#merged_topic_info.to_csv('topic_info_std.csv')
# Out:
#    orig_topic   Topic        Freq   ...          Total  loglift  logprob
# 0           2  Topic1  113.650689   ...     114.282459   1.2864  -3.7361
# 1           2  Topic1  106.751725   ...     107.382346   1.2860  -3.7987
# 2           2  Topic1   84.162680   ...      84.792740   1.2844  -4.0365
# 3           2  Topic1   78.390507   ...      79.016127   1.2839  -4.1075
# 4           2  Topic1   76.035493   ...      76.650908   1.2838  -4.1380
# 5           2  Topic1   76.035493   ...      76.650908   1.2838  -4.1380
# 6           2  Topic1   78.743070   ...      79.382475   1.2838  -4.1030
# 7           2  Topic1   73.806420   ...      74.429781   1.2835  -4.1678
# 8           2  Topic1   69.339913   ...      69.964438   1.2829  -4.2302
# 9           2  Topic1   54.210871   ...      54.824744   1.2806  -4.4763
#
# [10 rows x 7 columns]

# %%
merged_comments= pd.merge(topic_map,comments_tab,on="orig_topic",how='inner')
merged_comments.head(10)
# Out:
#    orig_topic   Topic    ...            2         3
# 0           2  Topic1    ...     0.949468  0.016917
# 1           2  Topic1    ...     0.942130  0.019242
# 2           2  Topic1    ...     0.941849  0.019387
# 3           2  Topic1    ...     0.924875  0.025109
# 4           2  Topic1    ...     0.924677  0.025084
# 5           2  Topic1    ...     0.924484  0.025012
# 6           2  Topic1    ...     0.916627  0.027801
# 7           2  Topic1    ...     0.916407  0.027798
# 8           2  Topic1    ...     0.916356  0.027801
# 9           2  Topic1    ...     0.906180  0.031273
#
# [10 rows x 7 columns]

# %%
merged_comments.rename(columns=diccionario['Topic'], inplace=True) #using the dictonary to rename columns using topic_map above

# %%
print(merged_comments.columns)
# Out:
# Index(['orig_topic', 'Topic', 'lider_minus', 'Topic2', 'Topic4', 'Topic1',
#        'Topic3'],
#       dtype='object')

# %%
merged_comments.head(10)
# Out:
#    orig_topic   Topic    ...       Topic1    Topic3
# 0           2  Topic1    ...     0.949468  0.016917
# 1           2  Topic1    ...     0.942130  0.019242
# 2           2  Topic1    ...     0.941849  0.019387
# 3           2  Topic1    ...     0.924875  0.025109
# 4           2  Topic1    ...     0.924677  0.025084
# 5           2  Topic1    ...     0.924484  0.025012
# 6           2  Topic1    ...     0.916627  0.027801
# 7           2  Topic1    ...     0.916407  0.027798
# 8           2  Topic1    ...     0.916356  0.027801
# 9           2  Topic1    ...     0.906180  0.031273
#
# [10 rows x 7 columns]

# %%
merged_comments.to_csv('topicdb_std.csv')

# %%
#print(dash.token_table)
tok_table=pd.DataFrame(dash.token_table)
tok_table.head(10)
tok_table.to_csv('tok_table2.csv')

# %%
#pyLDAvis.enable_notebook()
#dash = pyLDAvis.sklearn.prepare(nmf, data_vectorized, vectorizer, mds='tsne')
#dash

# %% [markdown]
# ## Cómo interpretar ésta gráfica?
# 1. Los temas están a la izquierda y sus palabras respectivas a la derecha.
# 2. Los temas más grandes con más frecuents y entre más cercanos más parecidos son.
# 3. La selección de las palabras está basada en su capacidad de diferenciación y frecuencia.
#
# **Selecciona el tema para ver sus palabras correspondientes.**

# %% [markdown]
# ## Biagram spaCy tokenizer para la identificación de temas

# %%
def spacy_bigram_tokenizer(phrase):
    doc = parser(phrase) # create spacy object
    token_not_noun = []
    notnoun_noun_list = []
    noun = ""

    for item in doc:
        if item.pos_ != "NOUN": # separate nouns and not nouns
            token_not_noun.append(item.text)
        if item.pos_ == "NOUN":
            noun = item.text
        
        for notnoun in token_not_noun:
            notnoun_noun_list.append(notnoun + " " + noun)

    return " ".join([i for i in notnoun_noun_list])

# %%
bivectorizer = CountVectorizer(min_df=5, max_df=0.9, lowercase=True, ngram_range=(1,2))
bigram_vectorized = bivectorizer.fit_transform(wines["processed_source"])

# %% [markdown]
# ## LDA para información procesada con Biagram

# %%
bi_lda = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=10, learning_method='online',verbose=True)
data_bi_lda = bi_lda.fit_transform(bigram_vectorized)
# Out:
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10

# %% [markdown]
# ### Temas pare el modelo de bigram

# %%
print("Bi-LDA Model:")
selected_topics(bi_lda, bivectorizer)
# Out:
# Bi-LDA Model:
# Topic 0:
# ['escuchar', 'colaboradores', 'personas', 'caracter', 'forma', 'trato', 'decisiones', 'clientes', 'laboral', 'humildad']
# Topic 1:
# ['equipo', 'falta', 'comunicación', 'organización', 'apoyo', 'ocasiones', 'organizacion', 'mejorar', 'confianza', 'puesto']
# Topic 2:
# ['persona', 'lider', 'oportunidad', 'acompañamiento', 'falta', 'aprender', 'situaciones', 'colaboradores', 'reconocer', 'areas']
# Topic 3:
# ['gente', 'campo', 'seguimiento', 'personal', 'áreas', 'crecimiento', 'paciencia', 'carácter', 'comunicacion', 'cargo']

# %%
bi_dash = pyLDAvis.sklearn.prepare(bi_lda, bigram_vectorized, bivectorizer, mds='tsne')
bi_dash
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 1      351.755249 -279.098785       1        1  29.378274
# 0       77.331848   25.298946       2        1  25.756346
# 3     -227.021927 -249.173996       3        1  23.174422
# 2       47.402157 -553.571777       4        1  21.690959, topic_info=     Category        Freq   ...     loglift  logprob
# term                        ...
# 265   Default  429.000000   ...     30.0000  30.0000
# 279   Default  198.000000   ...     29.0000  29.0000
# 541   Default  138.000000   ...     28.0000  28.0000
# 132   Default  119.000000   ...     27.0000  27.0000
# 518   Default  118.000000   ...     26.0000  26.0000
# 115   Default  168.000000   ...     25.0000  25.0000
# 89    Default   88.000000   ...     24.0000  24.0000
# 432   Default   81.000000   ...     23.0000  23.0000
# 360   Default   94.000000   ...     22.0000  22.0000
# 497   Default  100.000000   ...     21.0000  21.0000
# 644   Default   82.000000   ...     20.0000  20.0000
# 516   Default   91.000000   ...     19.0000  19.0000
# 96    Default   81.000000   ...     18.0000  18.0000
# 459   Default   88.000000   ...     17.0000  17.0000
# 510   Default  125.000000   ...     16.0000  16.0000
# 590   Default   86.000000   ...     15.0000  15.0000
# 43    Default  145.000000   ...     14.0000  14.0000
# 199   Default   74.000000   ...     13.0000  13.0000
# 320   Default  264.000000   ...     12.0000  12.0000
# 545   Default  123.000000   ...     11.0000  11.0000
# 109   Default   72.000000   ...     10.0000  10.0000
# 18    Default   80.000000   ...      9.0000   9.0000
# 718   Default   64.000000   ...      8.0000   8.0000
# 597   Default   77.000000   ...      7.0000   7.0000
# 277   Default   76.000000   ...      6.0000   6.0000
# 13    Default   59.000000   ...      5.0000   5.0000
# 542   Default  123.000000   ...      4.0000   4.0000
# 137   Default   93.000000   ...      3.0000   3.0000
# 178   Default   60.000000   ...      2.0000   2.0000
# 527   Default   58.000000   ...      1.0000   1.0000
# ...       ...         ...   ...         ...      ...
# 50     Topic4   49.381280   ...      1.5137  -4.0475
# 662    Topic4   46.988782   ...      1.5129  -4.0971
# 53     Topic4   42.271987   ...      1.5115  -4.2029
# 610    Topic4   42.359053   ...      1.5114  -4.2009
# 227    Topic4   40.552744   ...      1.5105  -4.2444
# 500    Topic4   39.147856   ...      1.5101  -4.2797
# 544    Topic4   36.824570   ...      1.5088  -4.3409
# 578    Topic4   36.644329   ...      1.5087  -4.3458
# 483    Topic4   36.130778   ...      1.5083  -4.3599
# 560    Topic4   34.896377   ...      1.5075  -4.3947
# 147    Topic4   34.250206   ...      1.5074  -4.4133
# 535    Topic4   34.694675   ...      1.5073  -4.4005
# 158    Topic4   27.821410   ...      1.5027  -4.6212
# 245    Topic4   27.866357   ...      1.5023  -4.6196
# 420    Topic4   27.271820   ...      1.5022  -4.6412
# 122    Topic4   25.538793   ...      1.5007  -4.7068
# 528    Topic4   23.173848   ...      1.4977  -4.8040
# 54     Topic4   22.518300   ...      1.4973  -4.8327
# 437    Topic4   23.109503   ...      1.4972  -4.8068
# 69     Topic4   22.424442   ...      1.4964  -4.8369
# 141    Topic4   21.971821   ...      1.4959  -4.8573
# 88     Topic4   21.887291   ...      1.4959  -4.8611
# 300    Topic4   21.665019   ...      1.4957  -4.8713
# 636    Topic4   21.316934   ...      1.4952  -4.8875
# 631    Topic4   21.338382   ...      1.4951  -4.8865
# 260    Topic4   22.004868   ...      1.4948  -4.8558
# 191    Topic4   21.203501   ...      1.4944  -4.8929
# 510    Topic4   74.160526   ...      1.0009  -3.6408
# 115    Topic4   44.304183   ...      0.1933  -4.1560
# 320    Topic4   51.605539   ...     -0.1041  -4.0034
#
# [174 rows x 6 columns], token_table=      Topic      Freq               Term
# term
# 10        1  0.985988       acercamiento
# 13        4  0.995816     acompañamiento
# 15        3  0.991534            actitud
# 18        1  0.986347        actividades
# 27        2  0.976583            ahorita
# 37        2  0.981672           apertura
# 38        2  0.987537              apoya
# 39        2  0.978788             apoyar
# 43        1  0.754073              apoyo
# 43        3  0.239932              apoyo
# 50        4  0.977877           aprender
# 53        4  0.977010              areas
# 54        4  0.990242  areas oportunidad
# 62        1  0.988476           atencion
# 63        1  0.834688           atención
# 63        4  0.153758           atención
# 68        1  0.989971             aveces
# 69        4  0.950340              ayuda
# 81        3  0.976486             buscar
# 86        3  0.945783            cambiar
# 88        4  0.973136            cambios
# 89        3  0.994838              campo
# 90        2  0.971399          capacidad
# 96        2  0.989770           caracter
# 98        3  0.712187              cargo
# 98        4  0.290150              cargo
# 100       1  0.359966           carácter
# 100       3  0.629941           carácter
# 108       2  0.975805            cliente
# 109       2  0.985827           clientes
# ...     ...       ...                ...
# 586       3  0.681724         promotores
# 590       1  0.993556             puesto
# 596       1  0.984719            puntual
# 597       1  0.994524        puntualidad
# 610       4  0.974938          reconocer
# 622       2  0.992990    responsabilidad
# 624       3  0.975447        responsable
# 628       3  0.979710         resultados
# 631       4  0.952012  retroalimentacion
# 633       1  0.971140  retroalimentación
# 636       4  0.953046          reuniones
# 641       3  0.960909              salir
# 644       3  0.994970        seguimiento
# 646       3  0.973969             seguir
# 657       2  0.968609           servicio
# 662       4  0.984977        situaciones
# 676       2  0.967383       subordinados
# 682       3  0.977791              tacto
# 687       2  0.978613              temas
# 689       1  0.992570            tiempos
# 691       3  0.950187         tolerancia
# 692       3  0.951816          tolerante
# 693       2  0.972767              tomar
# 697       3  0.989520             tratar
# 700       2  0.838629              trato
# 700       3  0.154484              trato
# 706       3  0.971320             unidad
# 711       3  0.986951             ventas
# 718       3  0.981425              áreas
# 719       3  0.993388  áreas oportunidad
#
# [153 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 4, 3])

# %%
import pandas as pd
master_list = [['cat', 123, 'yellow'], ['dog', 12345, 'green'], ['horse', 123456, 'red']]
df = pd.DataFrame(master_list)

df
# Out:
#        0       1       2
# 0    cat     123  yellow
# 1    dog   12345   green
# 2  horse  123456     red

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.colheader_justify','light', 'display.width', 2000, 'display.max_colwidth', 500):
    df = df.stack().str.lstrip().unstack()
    df = df.style.set_properties(**{'text-align': 'left'})
df
# Out:
# <style  type="text/css" >
#     #T_be954e22_1d72_11eb_b56d_6d0a3948f444row0_col0 {
#             text-align:  left;
#         }    #T_be954e22_1d72_11eb_b56d_6d0a3948f444row0_col1 {
#             text-align:  left;
#         }    #T_be954e22_1d72_11eb_b56d_6d0a3948f444row0_col2 {
#             text-align:  left;
#         }    #T_be954e22_1d72_11eb_b56d_6d0a3948f444row1_col0 {
#             text-align:  left;
#         }    #T_be954e22_1d72_11eb_b56d_6d0a3948f444row1_col1 {
#             text-align:  left;
#         }    #T_be954e22_1d72_11eb_b56d_6d0a3948f444row1_col2 {
#             text-align:  left;
#         }    #T_be954e22_1d72_11eb_b56d_6d0a3948f444row2_col0 {
#             text-align:  left;
#         }    #T_be954e22_1d72_11eb_b56d_6d0a3948f444row2_col1 {
#             text-align:  left;
#         }    #T_be954e22_1d72_11eb_b56d_6d0a3948f444row2_col2 {
#             text-align:  left;
#         }</style>
# <table id="T_be954e22_1d72_11eb_b56d_6d0a3948f444" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_be954e22_1d72_11eb_b56d_6d0a3948f444level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row0_col0" class="data row0 col0" >cat</td>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row0_col1" class="data row0 col1" >nan</td>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row0_col2" class="data row0 col2" >yellow</td>
#     </tr>    <tr>
#         <th id="T_be954e22_1d72_11eb_b56d_6d0a3948f444level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row1_col0" class="data row1 col0" >dog</td>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row1_col1" class="data row1 col1" >nan</td>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row1_col2" class="data row1 col2" >green</td>
#     </tr>    <tr>
#         <th id="T_be954e22_1d72_11eb_b56d_6d0a3948f444level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row2_col0" class="data row2 col0" >horse</td>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row2_col1" class="data row2 col1" >nan</td>
#         <td id="T_be954e22_1d72_11eb_b56d_6d0a3948f444row2_col2" class="data row2 col2" >red</td>
#     </tr></tbody>
# </table>

# %%
from collections import Counter
topics = lda.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-305-f1dc50434b42> in <module>
#       1 from collections import Counter
# ----> 2 topics = lda.show_topics(formatted=False)
#       3 data_flat = [w for w_list in data_ready for w in w_list]
#       4 counter = Counter(data_flat)
#       5
#
# AttributeError: 'LatentDirichletAllocation' object has no attribute 'show_topics'

# %%
doc_topic

# %% [raw]
# dir(bi_dash)

# %%
dir(LatentDirichletAllocation)

# %%
dir(selected_topics)

# %%
dir(lda)

# %%
selected_topics
